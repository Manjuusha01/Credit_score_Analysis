# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING THE DATA

# %%
credit_data = pd.read_csv('/content/credit.csv')
credit_data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
credit_data.shape
# Out:
# (100000, 28)

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
credit_data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
credit_data.describe(include='object').T
# Out:
#                         count unique                             top   freq
# Name                   100000  10128                        Jessicad     48
# Occupation             100000     15                          Lawyer   7096
# Type_of_Loan           100000   6261                         No Data  11408
# Credit_Mix             100000      3                        Standard  45848
# Payment_of_Min_Amount  100000      3                             Yes  52326
# Payment_Behaviour      100000      6  Low_spent_Small_value_payments  28616
# Credit_Score           100000      3                        Standard  53174

# %% [markdown]
# Checking the Null values

# %%
credit_data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
credit_data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %% [markdown]
# Drop the columns which are Irrelevnt to the Data

# %%
credit_data.drop(['ID','Customer_ID','Month','Name','SSN'],axis=1,inplace=True)

# %%
credit_data.head()
# Out:
#     Age Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  23.0  Scientist       19114.12            1824.843333                3.0
# 1  23.0  Scientist       19114.12            1824.843333                3.0
# 2  23.0  Scientist       19114.12            1824.843333                3.0
# 3  23.0  Scientist       19114.12            1824.843333                3.0
# 4  23.0  Scientist       19114.12            1824.843333                3.0
#
#    Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0              4.0            3.0          4.0
# 1              4.0            3.0          4.0
# 2              4.0            3.0          4.0
# 3              4.0            3.0          4.0
# 4              4.0            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# ...

# %% [markdown]
# DATA PREPROCESSING

# %%
credit_data.dtypes
# Out:
# Age                         float64
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date         float64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
credit_data['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# Standard    45848
# Good        30384
# Bad         23768
# Name: count, dtype: int64

# %%
credit_data['Credit_Mix'].replace({'Standard':1,'Good':2,'Bad':3})
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 99995    2
# 99996    2
# 99997    2
# 99998    2
# 99999    2
# Name: Credit_Mix, Length: 100000, dtype: int64

# %%
credit_data['Credit_Score'].value_counts()
# Out:
# Credit_Score
# Standard    53174
# Poor        28998
# Good        17828
# Name: count, dtype: int64

# %%
credit_data['Credit_Score'].replace({'Standard':1,'Poor':2,'Good':3})
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 99995    2
# 99996    2
# 99997    2
# 99998    1
# 99999    2
# Name: Credit_Score, Length: 100000, dtype: int64

# %%
credit_data['Occupation'].value_counts()
# Out:
# Occupation
# Lawyer           7096
# Engineer         6864
# Architect        6824
# Mechanic         6776
# Scientist        6744
# Accountant       6744
# Developer        6720
# Media_Manager    6720
# Teacher          6672
# Entrepreneur     6648
# Doctor           6568
# Journalist       6536
# Manager          6432
# Musician         6352
# Writer           6304
# Name: count, dtype: int64

# %%
credit_data['Occupation']=credit_data['Occupation'].replace('_______',np.nan)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Occupation', hue='Credit_Score', data=credit_data)
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Count of Another_Categorical_Variable by Occupation')
plt.xticks(rotation=45)
plt.legend(title='Another_Categorical_Variable')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
credit_data['Payment_of_Min_Amount'].value_counts()
# Out:
# Payment_of_Min_Amount
# Yes    52326
# No     35667
# NM     12007
# Name: count, dtype: int64

# %%
credit_data['Payment_of_Min_Amount'].replace({'Yes':1,'No':2,'NM':3})
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 99995    2
# 99996    2
# 99997    2
# 99998    2
# 99999    2
# Name: Payment_of_Min_Amount, Length: 100000, dtype: int64

# %%
credit_data['Payment_Behaviour'].value_counts()
# Out:
# Payment_Behaviour
# Low_spent_Small_value_payments      28616
# High_spent_Medium_value_payments    19738
# High_spent_Large_value_payments     14726
# Low_spent_Medium_value_payments     14399
# High_spent_Small_value_payments     11764
# Low_spent_Large_value_payments      10757
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Payment_Behaviour', hue='Credit_Score', data=credit_data)
plt.xlabel('Payment_Behaviour')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Another_Categorical_Variable')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
credit_data['Payment_Behaviour'].replace({'Low_spent_Small_value_payments':1,'High_spent_Medium_value_payments':2,'High_spent_Large_value_payments':3,'Low_spent_Medium_value_payments':4,'High_spent_Small_value_payments':5,'Low_spent_Large_value_payments':6})
# Out:
# 0        5
# 1        6
# 2        4
# 3        1
# 4        2
#         ..
# 99995    3
# 99996    2
# 99997    3
# 99998    6
# 99999    2
# Name: Payment_Behaviour, Length: 100000, dtype: int64

# %%
credit_data['Type_of_Loan'].value_counts()
# Out:
# Type_of_Loan
# No Data                                                                                                                               11408
# Not Specified                                                                                                                          1408
# Credit-Builder Loan                                                                                                                    1280
# Personal Loan                                                                                                                          1272
# Debt Consolidation Loan                                                                                                                1264
#                                                                                                                                       ...
# ...

# %% [markdown]
# Data Cleaning

# %%
print(credit_data['Monthly_Inhand_Salary'])
# Out:
# 0        1824.843333
# 1        1824.843333
# 2        1824.843333
# 3        1824.843333
# 4        1824.843333
#             ...
# 99995    3359.415833
# 99996    3359.415833
# 99997    3359.415833
# 99998    3359.415833
# 99999    3359.415833
# Name: Monthly_Inhand_Salary, Length: 100000, dtype: float64

# %%
credit_data['Monthly_Inhand_Salary'].unique()
# Out:
# array([ 1824.84333333,  3037.98666667, 12187.22      , ...,
#         3097.00833333,  1929.90666667,  3359.41583333])

# %%
mean_salary = credit_data["Monthly_Inhand_Salary"].mean()
credit_data["Monthly_Inhand_Salary"].fillna(mean_salary, inplace=True)

# %%
print(mean_salary)
# Out:
# 4197.270834892953

# %%
print(credit_data['Age'])
# Out:
# 0        23.0
# 1        23.0
# 2        23.0
# 3        23.0
# 4        23.0
#          ...
# 99995    25.0
# 99996    25.0
# 99997    25.0
# 99998    25.0
# 99999    25.0
# Name: Age, Length: 100000, dtype: float64

# %%
credit_data['Age'].value_counts()
# Out:
# Age
# 38.0    3070
# 28.0    3045
# 31.0    3037
# 26.0    3025
# 32.0    2969
# 36.0    2953
# 25.0    2952
# 27.0    2951
# 35.0    2940
# 39.0    2927
# 34.0    2922
# 44.0    2902
# 22.0    2890
# 19.0    2875
# 41.0    2865
# 20.0    2833
# 37.0    2832
# 29.0    2823
# 43.0    2809
# 30.0    2807
# 21.0    2792
# 24.0    2789
# 23.0    2719
# 45.0    2712
# 40.0    2695
# 42.0    2643
# 33.0    2623
# 18.0    2427
# 46.0    1670
# 15.0    1615
# 17.0    1551
# 16.0    1505
# 49.0    1419
# 48.0    1416
# 55.0    1395
# 53.0    1394
# 52.0    1388
# 54.0    1342
# 51.0    1332
# 50.0    1305
# 47.0    1265
# 14.0    1197
# 56.0     379
# Name: count, dtype: int64

# %%
print(credit_data['Age'].unique())
# Out:
# [23. 28. 34. 54. 55. 21. 31. 33. 30. 24. 44. 45. 40. 41. 32. 35. 36. 39.
#  37. 20. 46. 26. 42. 19. 48. 38. 43. 22. 16. 18. 15. 27. 25. 14. 17. 47.
#  53. 56. 29. 49. 51. 50. 52.]

# %%
plt.figure(figsize=(12, 7))
sns.countplot(x='Age', data=credit_data)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
credit_data['Age'].plot(kind='box')
plt.show()

# %%
credit_data["Age"] = pd.to_numeric(credit_data["Age"], errors="coerce")
age_mean=credit_data["Age"].mean()
credit_data["Age"].fillna(age_mean, inplace=True)

# %%
print(age_mean)
# Out:
# 33.31634

# %% [markdown]
# Occupation VS Credit score

# %%
sns.catplot(x='Credit_Score', col='Occupation', data=credit_data, kind='count', col_wrap=4)

# %%
credit_data['Credit_History_Age'].value_counts()
# Out:
# Credit_History_Age
# 190.0    488
# 232.0    485
# 191.0    484
# 215.0    483
# 213.0    483
#         ...
# 3.0       21
# 2.0       15
# 403.0     15
# 404.0     15
# 1.0        2
# Name: count, Length: 404, dtype: int64

# %%
credit_data['Annual_Income'].value_counts()
# Out:
# Annual_Income
# 20867.670    16
# 9141.630     16
# 32543.380    16
# 40341.160    16
# 22434.160    16
#              ..
# 18317.260     8
# 14784.450     8
# 60573.960     8
# 18413.795     8
# 39628.990     8
# Name: count, Length: 12488, dtype: int64

# %%
credit_data['Annual_Income'].unique()
# Out:
# array([ 19114.12,  34847.84, 143162.64, ...,  37188.1 ,  20002.88,
#         39628.99])

# %%
sns.boxplot(x = 'Annual_Income', data = credit_data)
# Out:
# <Axes: xlabel='Annual_Income'>

# %%
credit_data["Annual_Income"] = pd.to_numeric(credit_data["Annual_Income"], errors="coerce")
an_mean=credit_data["Annual_Income"].mean()
credit_data["Annual_Income"].fillna(an_mean, inplace=True)

# %%
print(an_mean)
# Out:
# 50505.12344879999

# %%
credit_data['Num_of_Loan'].value_counts()
# Out:
# Num_of_Loan
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 0.0    11408
# 1.0    11128
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: count, dtype: int64

# %%
credit_data["Num_of_Loan"] = pd.to_numeric(credit_data["Num_of_Loan"], errors="coerce")
num_mean=credit_data["Num_of_Loan"].mean()
credit_data["Num_of_Loan"].fillna(num_mean, inplace=True)

# %%
print(num_mean)
# Out:
# 3.53288

# %%
credit_data['Changed_Credit_Limit'] = credit_data['Changed_Credit_Limit'].replace('-', np.nan)

# %%
credit_data['Changed_Credit_Limit'] = pd.to_numeric(credit_data['Changed_Credit_Limit'], errors='coerce')

# %%
mean_value = credit_data['Changed_Credit_Limit'].mean()
credit_data['Changed_Credit_Limit'].fillna(mean_value, inplace=True)

# %%
credit_data['Num_Credit_Inquiries'].unique()
# Out:
# array([ 4.,  2.,  3.,  5.,  9.,  8.,  7.,  6.,  0.,  1., 10., 11., 12.,
#        17., 13., 14., 16., 15.])

# %%
credit_data['Interest_Rate'] = credit_data['Interest_Rate'].astype(float)

# %%
credit_data.Interest_Rate.value_counts()
# Out:
# Interest_Rate
# 8.0     5104
# 5.0     5096
# 6.0     4832
# 12.0    4648
# 10.0    4616
# 7.0     4584
# 9.0     4576
# 11.0    4512
# 18.0    4192
# 15.0    4072
# 20.0    4008
# 17.0    3888
# 16.0    3800
# 19.0    3704
# 3.0     2824
# 1.0     2744
# 4.0     2640
# 2.0     2520
# 13.0    2432
# 14.0    2272
# 32.0    1776
# 22.0    1752
# 24.0    1736
# 30.0    1728
# 23.0    1720
# 29.0    1696
# 28.0    1648
# 27.0    1640
# 25.0    1608
# 21.0    1592
# 34.0    1528
# 26.0    1528
# 33.0    1496
# 31.0    1488
# Name: count, dtype: int64

# %%
credit_data.drop(['Type_of_Loan'], axis = 1, inplace = True)

# %% [markdown]
# Data Visualization

# %%
df_numeric_cols = [col for col in credit_data.columns if credit_data[col].dtype in ['int64', 'float64']]

plt.figure(figsize=(15,15))
for i, col in enumerate(df_numeric_cols):
    plt.subplot(5, 4, i+1)
    sns.boxplot(x='Credit_Score', y=col, data=credit_data)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
num=credit_data.select_dtypes(include=[np.number])

# %%
corr=num.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=credit_data, x="Age", y="Annual_Income")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=credit_data, x="Total_EMI_per_month", kde=True,bins=30,color="orange")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=credit_data, x="Annual_Income", kde=True,bins=30,hue="Credit_Score")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=credit_data[["Total_EMI_per_month", "Amount_invested_monthly","Monthly_Balance"]], orient="h")
plt.show()

# %% [markdown]
# Outlier Handling

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class ClipOutliersTransformer(BaseEstimator, TransformerMixin):
    def __init__(self,
                 lower_quantile,
                 upper_quantile,
                 multiply_by=1.5,
                 replace_with_median: bool = False):
        self.lower_quantile = lower_quantile
        self.upper_quantile = upper_quantile
        self.multiply_by = multiply_by
        self.replace_with_median = replace_with_median

        self.lower_limit = 0
        self.upper_limit = 0
        self.feature_names_in_ = None

    def fit(self, X, y=None):
        q1, q3 = np.quantile(X, [self.lower_quantile, self.upper_quantile])
        iqr = q3 - q1
        self.lower_limit = q1 - (self.multiply_by * iqr)
        self.upper_limit = q3 + (self.multiply_by * iqr)
        return self

    def transform(self, X):
        if self.replace_with_median:
            return np.where(
                ((X >= self.lower_limit) & (X <= self.upper_limit)), X,
                np.median(X))
        else:
            return np.clip(X, self.lower_limit, self.upper_limit)


def get_skewness(df, lower=None, upper=None):
    columns = df.columns
    skewness: pd.Series = df[columns].skew()
    highly_skewed = skewness[(skewness <= lower) |
                             (skewness >= upper)].index.to_list()
    lowly_skewed = skewness[(skewness > lower)
                            & (skewness < upper)].index.to_list()
    return (highly_skewed, lowly_skewed)

# %% [markdown]
# Saving the new Dataset

# %%
credit_data.to_csv("CreditScoreClassification.csv", index=False)

# %%
credit_data = pd.read_csv('CreditScoreClassification.csv')
credit_data.head()
# Out:
#         Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0 -0.958344  Scientist      -0.819625              -0.744544
# 1 -0.958344  Scientist      -0.819625              -0.744544
# 2 -0.958344  Scientist      -0.819625              -0.744544
# 3 -0.958344  Scientist      -0.819625              -0.744544
# 4 -0.958344  Scientist      -0.819625              -0.744544
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
# 3                3.0              4.0            3.0          4.0
# 4                3.0              4.0            3.0          4.0
#
#    Delay_from_due_date  Num_of_Delayed_Payment  ...  Credit_Mix  \
# 0                  3.0                     7.0  ...        Good
# 1                  3.0                     4.0  ...        Good
# ...

# %%
credit_data['Annual_Income'] = credit_data['Annual_Income'].abs()

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
credit_data["Credit_Score"] = LabelEncoder().fit_transform(credit_data["Credit_Score"])
credit_data["Credit_Score"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    2
# 99999    1
# Name: Credit_Score, Length: 100000, dtype: int64

# %%
credit_data["Credit_Score"].value_counts()
# Out:
# Credit_Score
# 2    53174
# 1    28998
# 0    17828
# Name: count, dtype: int64

# %%
# select columns of type 'object'
credit_data.select_dtypes(include=['object']).columns
# Out:
# Index(['Occupation', 'Credit_Mix', 'Payment_of_Min_Amount',
#        'Payment_Behaviour'],
#       dtype='object')

# %%
payment_behaviour_categories = ['Low_spent_Small_value_payments',
                                'Low_spent_Medium_value_payments',
                                'Low_spent_Large_value_payments',
                                'High_spent_Small_value_payments',
                                'High_spent_Medium_value_payments',
                                'High_spent_Large_value_payments']

payment_behaviour_encoder = OrdinalEncoder(categories=[payment_behaviour_categories])

credit_data['Payment_Behaviour'] = payment_behaviour_encoder.fit_transform(credit_data[['Payment_Behaviour']])

# %%
label_encoder = LabelEncoder()
credit_data['Payment_of_Min_Amount'] = label_encoder.fit_transform(credit_data['Payment_of_Min_Amount'])

# %%
label_encoder = LabelEncoder()
credit_data['Occupation'] = label_encoder.fit_transform(credit_data['Occupation'])

# %%
credit_data.head().T
# Out:
#                                                         0  \
# Age                                             -0.958344
# Occupation                                      Scientist
# Annual_Income                                   -0.819625
# Monthly_Inhand_Salary                           -0.744544
# Num_Bank_Accounts                                     3.0
# Num_Credit_Card                                       4.0
# Interest_Rate                                         3.0
# Num_of_Loan                                           4.0
# Delay_from_due_date                                   3.0
# Num_of_Delayed_Payment                                7.0
# Changed_Credit_Limit                                11.27
# Num_Credit_Inquiries                                  4.0
# Credit_Mix                                           Good
# Outstanding_Debt                                -0.533485
# Credit_Utilization_Ratio                        -1.067562
# ...

# %%
credit_data['Monthly_Balance']=credit_data['Monthly_Balance'].abs()

# %%
credit_data['Monthly_Balance'].value_counts()
# Out:
# Monthly_Balance
# 0.775871    8
# 3.923761    8
# 0.836258    7
# 0.552884    7
# 0.779790    7
#            ..
# 0.352401    1
# 1.143380    1
# 0.885737    1
# 0.584394    1
# 0.004841    1
# Name: count, Length: 98494, dtype: int64

# %%
credit_data['Annual_Income']=credit_data['Annual_Income'].abs()

# %%
credit_data['Monthly_Inhand_Salary']=credit_data['Monthly_Inhand_Salary'].abs()

# %%
credit_data['Outstanding_Debt']=credit_data['Outstanding_Debt'].abs()

# %%
credit_data['Credit_Utilization_Ratio']=credit_data['Credit_Utilization_Ratio'].abs()

# %%
credit_data['Total_EMI_per_month']=credit_data['Total_EMI_per_month'].abs()

# %%
credit_data['Amount_invested_monthly']=credit_data['Amount_invested_monthly'].abs()

# %%
credit_data.head()
# Out:
#         Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0 -0.958344  Scientist       0.819625               0.744544
# 1 -0.958344  Scientist       0.819625               0.744544
# 2 -0.958344  Scientist       0.819625               0.744544
# 3 -0.958344  Scientist       0.819625               0.744544
# 4 -0.958344  Scientist       0.819625               0.744544
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
# 3                3.0              4.0            3.0          4.0
# 4                3.0              4.0            3.0          4.0
#
#    Delay_from_due_date  Num_of_Delayed_Payment  ...  Credit_Mix  \
# 0                  3.0                     7.0  ...        Good
# 1                  3.0                     4.0  ...        Good
# ...

# %%
credit_data['Age'].value_counts()
# Out:
# Age
#  0.435092    3070
# -0.493865    3045
# -0.215178    3037
# -0.679657    3025
# -0.122282    2969
#  0.249301    2953
# -0.772552    2952
# -0.586761    2951
#  0.156405    2940
#  0.527988    2927
#  0.063509    2922
#  0.992466    2902
# -1.051240    2890
# -1.329927    2875
#  0.713779    2865
# -1.237031    2833
#  0.342196    2832
# -0.400970    2823
#  0.899571    2809
# -0.308074    2807
# -1.144135    2792
# -0.865448    2789
# -0.958344    2719
#  1.085362    2712
#  0.620883    2695
#  0.806675    2643
# -0.029387    2623
# -1.422823    2427
#  1.178258    1670
# -1.701510    1615
# -1.515718    1551
# -1.608614    1505
#  1.456945    1419
#  1.364049    1416
#  2.014319    1395
#  1.828528    1394
#  1.735632    1388
#  1.921424    1342
#  1.642736    1332
#  1.549841    1305
#  1.271154    1265
# -1.794405    1197
#  2.107215     379
# Name: count, dtype: int64

# %%
print(credit_data['Age'].describe())
# Out:
# count    1.000000e+05
# mean     3.202061e-16
# std      1.000005e+00
# min     -1.794405e+00
# 25%     -8.654482e-01
# 50%     -2.938663e-02
# 75%      8.066749e-01
# max      2.107215e+00
# Name: Age, dtype: float64

# %%
print(credit_data['Age'].head())
# Out:
# 0   -0.958344
# 1   -0.958344
# 2   -0.958344
# 3   -0.958344
# 4   -0.958344
# Name: Age, dtype: float64

# %% [markdown]
# Defining X AND Y

# %%
X = credit_data.drop("Credit_Score", axis=1)
y = credit_data.Credit_Score

# %%
y.value_counts(normalize=True)
# Out:
# Credit_Score
# 2    0.53174
# 1    0.28998
# 0    0.17828
# Name: proportion, dtype: float64

# %% [markdown]
# Spliting the Data into x_train and y_train

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15,
                                                    stratify=y, shuffle=True, random_state=42)

# %%
print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (85000, 21) (85000,)
# Testing set shape: (15000, 21) (15000,)
